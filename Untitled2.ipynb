# %% [markdown]
# <a href="https://colab.research.google.com/github/sintiaa28/DeapLearning/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir /content/Car

# %%
# !unzip /content/drive/MyDrive/deaplearning/car_images.zip -d /content/car
# Out:
# Archive:  /content/drive/MyDrive/deaplearning/car_images.zip
#   inflating: /content/car/Cars Dataset/test/Audi/1000.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1003.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1008.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1020.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1022.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1025.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1027.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1038.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/104.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1043.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1051.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1059.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1060.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1064.jpg
#   inflating: /content/car/Cars Dataset/test/Audi/1066.jpg
# ...

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/content/driver/Car/car'):
        print(os.path.join(dirname))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Convolution2D,MaxPooling2D,Flatten
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import HTML

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
IMAGE_SIZE = 128

train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        horizontal_flip=True
)
train_generator = train_datagen.flow_from_directory(
        '/content/car/Cars_Dataset/train',
        target_size=(IMAGE_SIZE,IMAGE_SIZE),
        class_mode="sparse",
)
# Out:
# Found 3352 images belonging to 7 classes.

# %%
count=0
for image_batch, label_batch in train_generator:
#     print(label_batch)
    print(image_batch[0])
    break
# Out:
# [[[0.27915758 0.3370548  0.18967159]
#   [0.26737392 0.32474738 0.1805065 ]
#   [0.2555902  0.31243998 0.1713414 ]
#   ...
#   [0.23373781 0.26511034 0.17491427]
#   [0.2081356  0.23950817 0.14687937]
#   [0.27399984 0.3053724  0.21125476]]
#
#  [[0.36292458 0.42715853 0.24026588]
#   [0.36737618 0.43134832 0.24628866]
#   [0.3718278  0.43553808 0.2523114 ]
#   ...
#   [0.23609455 0.2674671  0.17727101]
#   [0.20394585 0.23531839 0.14242776]
#   [0.28368866 0.3150612  0.22094357]]
#
#  [[0.32304874 0.38971543 0.1813535 ]
#   [0.3227869  0.38945356 0.18187723]
#   [0.32252505 0.38919172 0.18240094]
#   ...
#   [0.23845129 0.26982385 0.17962775]
#   [0.1997561  0.23112865 0.13797614]
#   [0.2933775  0.32475004 0.2306324 ]]
#
#  ...
#
#  [[0.463745   0.40884304 0.37354892]
#   [0.45200655 0.3971046  0.36181048]
#   [0.44791928 0.3930173  0.35772318]
#   ...
#   [0.482161   0.45078844 0.40765116]
#   [0.48425585 0.4528833  0.40974605]
#   [0.48635074 0.4549782  0.41184095]]
#
# ...

# %%
class_names = list(train_generator.class_indices.keys())
class_names
# Out:
# ['Audi',
#  'Hyundai Creta',
#  'Mahindra Scorpio',
#  'Rolls Royce',
#  'Swift',
#  'Tata Safari',
#  'Toyota Innova']

# %%
test_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        horizontal_flip=True)

test_generator = test_datagen.flow_from_directory(
        '/content/car/Cars_Dataset/test',
        target_size=(IMAGE_SIZE,IMAGE_SIZE),
        class_mode="sparse"
)
# Out:
# Found 813 images belonging to 7 classes.

# %%
for image_batch, label_batch in test_generator:
    print(image_batch[0])
    break
# Out:
# [[[0.4085384  0.42422467 0.46736193]
#   [0.42314357 0.43882984 0.4819671 ]
#   [0.4189211  0.4346074  0.47774464]
#   ...
#   [0.12028285 0.1516554  0.20263581]
#   [0.12038802 0.15176058 0.20274097]
#   [0.12049318 0.15186574 0.20284614]]
#
#  [[0.40822285 0.42390913 0.4670464 ]
#   [0.4227229  0.43840918 0.48154643]
#   [0.4192366  0.43492287 0.47806013]
#   ...
#   [0.12248017 0.15385272 0.20483312]
#   [0.12156864 0.15294118 0.20392159]
#   [0.12156864 0.15294118 0.20392159]]
#
#  [[0.3102706  0.32595688 0.36909416]
#   [0.31646243 0.3321487  0.37528595]
#   [0.30649093 0.3221772  0.36531445]
#   ...
#   [0.12566368 0.15703624 0.20801663]
#   [0.12430677 0.15567932 0.2066597 ]
#   [0.12441193 0.15578449 0.20676488]]
#
#  ...
#
#  [[0.47784093 0.5366644  0.6974488 ]
#   [0.47931325 0.5381368  0.6989211 ]
#   [0.4793235  0.5381471  0.6989314 ]
#   ...
#   [0.4119704  0.49332595 0.638424  ]
#   [0.36620712 0.44735235 0.5924504 ]
#   [0.32835004 0.40928495 0.554383  ]]
#
# ...

# %%
sz = 128

model = Sequential()

model.add(Convolution2D(32, (3, 3), input_shape=(sz, sz, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(units=96, activation='relu'))
model.add(Dropout(0.40))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=7, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 96)                2764896
#
#  dropout (Dropout)           (None, 96)                0
#
#  dense_1 (Dense)             (None, 32)                3104
#
#  dense_2 (Dense)             (None, 7)                 231
#
# ...
# Total params: 2,778,375
# Trainable params: 2,778,375
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=5
)
# Out:
# Epoch 1/5
# 105/105 [==============================] - 89s 850ms/step - loss: 1.8702 - accuracy: 0.2613 - val_loss: 1.7295 - val_accuracy: 0.3370
# Epoch 2/5
# 105/105 [==============================] - 89s 849ms/step - loss: 1.7421 - accuracy: 0.3431 - val_loss: 1.6445 - val_accuracy: 0.4379
# Epoch 3/5
# 105/105 [==============================] - 92s 881ms/step - loss: 1.6003 - accuracy: 0.4117 - val_loss: 1.4790 - val_accuracy: 0.4686
# Epoch 4/5
# 105/105 [==============================] - 91s 868ms/step - loss: 1.4850 - accuracy: 0.4573 - val_loss: 1.3672 - val_accuracy: 0.5092
# Epoch 5/5
# 105/105 [==============================] - 94s 892ms/step - loss: 1.3830 - accuracy: 0.4988 - val_loss: 1.3027 - val_accuracy: 0.5461

# %%
scores = model.evaluate(test_generator)
# Out:
# 26/26 [==============================] - 10s 369ms/step - loss: 1.2879 - accuracy: 0.5400

# %%
scores
# Out:
# [1.2878835201263428, 0.5399754047393799]

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
type(history.history['loss'])
# Out:
# list

# %%
len(history.history['loss'])
# Out:
# 5

# %%
history.history['loss'][:5]
# Out:
# [1.8702436685562134,
#  1.7420648336410522,
#  1.6003429889678955,
#  1.484951376914978,
#  1.3829984664916992]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
import matplotlib.pyplot as plt
EPOCHS = 5

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i])
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_generator:
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        
        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[int(labels[i])] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
    break
# Out:
# ...
# 1/1 [==============================] - 0s 26ms/step
